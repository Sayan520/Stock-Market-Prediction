# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
#Load the data and store the data into a data frame
data = pd.read_csv('TSLA Training.csv')
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-06-22  23.436001  23.483334  22.133333  22.242001  22.242001
# 1  2018-06-25  22.007999  22.564667  21.833332  22.200666  22.200666
# 2  2018-06-26  22.403334  22.903334  21.719999  22.799999  22.799999
# 3  2018-06-27  23.000000  23.386000  22.633333  22.966667  22.966667
# 4  2018-06-28  23.243999  23.801332  23.073999  23.328667  23.328667
#
#       Volume
# 0  153991500
# 1  103969500
# 2  111787500
# 3  125005500
# 4  125970000

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['Close'])
plt.title("Closing Price Of Tesla")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1257 non-null   object
#  1   Open       1257 non-null   float64
#  2   High       1257 non-null   float64
#  3   Low        1257 non-null   float64
#  4   Close      1257 non-null   float64
#  5   Adj Close  1257 non-null   float64
#  6   Volume     1257 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
#Plotting moving averages of 100 day
ma100 = data.Close.rolling(100).mean()
ma100
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 1252    188.0117
# 1253    189.1332
# 1254    190.2997
# 1255    191.5999
# 1256    192.5918
# Name: Close, Length: 1257, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(data.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %%
#Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
ma200 = data.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 1252    196.02555
# 1253    195.88095
# 1254    195.79515
# 1255    195.78935
# 1256    195.70085
# Name: Close, Length: 1257, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(data.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
#Get the number of rows and columns in the data set
data.shape
# Out:
# (1257, 7)

# %%
#Spliting the dataset into training (70%) and testing (30%) set
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (879, 7)
# (378, 7)

# %%
train.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-06-22  23.436001  23.483334  22.133333  22.242001  22.242001
# 1  2018-06-25  22.007999  22.564667  21.833332  22.200666  22.200666
# 2  2018-06-26  22.403334  22.903334  21.719999  22.799999  22.799999
# 3  2018-06-27  23.000000  23.386000  22.633333  22.966667  22.966667
# 4  2018-06-28  23.243999  23.801332  23.073999  23.328667  23.328667
#
#       Volume
# 0  153991500
# 1  103969500
# 2  111787500
# 3  125005500
# 4  125970000

# %%
test.head()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 879  2021-12-17  304.923340  320.220001  303.013336  310.856659  310.856659
# 880  2021-12-20  303.566681  307.230011  297.796661  299.980011  299.980011
# 881  2021-12-21  305.623322  313.166656  295.373322  312.843323  312.843323
# 882  2021-12-22  321.886658  338.553345  319.016663  336.290009  336.290009
# 883  2021-12-23  335.600006  357.660004  332.519989  355.666656  355.666656
#
#         Volume
# 879  100437300
# 880   56480100
# 881   71517900
# 882   93634200
# 883   92713200

# %%
#Create the training and testing data set
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
#Using MinMax scaler for normalization of the dataset
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.02590368],
#        [0.02579984],
#        [0.02730555],
#        [0.02772428],
#        [0.02863374],
#        [0.02746467],
#        [0.02614486],
#        [0.02208998],
#        [0.02180525],
#        [0.0217617 ],
#        [0.02337126],
#        [0.02403451],
#        [0.02344663],
#        [0.02306979],
#        [0.02343156],
#        [0.02196269],
#        [0.02407136],
#        [0.02426565],
#        [0.02365934],
#        [0.02254555],
#        [0.02080702],
#        [0.01984062],
#        [0.02173491],
#        [0.02138486],
#        [0.01979875],
#        [0.01862466],
#        [0.01995953],
#        [0.02041175],
#        [0.02856842],
#        [0.02833895],
#        [0.02730388],
#        [0.03359808],
#        [0.03205216],
#        [0.02905581],
#        [0.02956497],
#        [0.02971906],
#        [0.02825019],
#        [0.02675117],
#        [0.02620851],
#        [0.02119225],
#        [0.02168466],
#        [0.02393905],
#        [0.0238955 ],
#        [0.02363757],
#        [0.02409314],
#        [0.02349855],
#        [0.02225747],
#        [0.02111018],
#        [0.02079865],
#        [0.02054909],
#        [0.01842032],
#        [0.01704525],
#        [0.01708042],
#        [0.01411421],
#        [0.01784249],
#        [0.01682751],
#        [0.01868663],
#        [0.01850574],
#        [0.01946712],
#        [0.01940683],
#        [0.01775205],
#        [0.02010693],
#        [0.01999136],
#        [0.02012033],
#        [0.02021747],
#        [0.02043688],
#        [0.0218756 ],
#        [0.02153057],
#        [0.01437046],
#        [0.02206318],
#        [0.0204419 ],
#        [0.01940013],
#        [0.01722781],
#        [0.01389815],
#        [0.01199046],
#        [0.01404051],
#        [0.01304899],
#        [0.01227016],
#        [0.01336721],
#        [0.01350288],
#        [0.01635017],
#        [0.01554456],
#        [0.01422642],
#        [0.01357154],
#        [0.01373066],
#        [0.01928958],
#        [0.01834495],
#        [0.02275993],
#        [0.02544644],
#        [0.02610802],
#        [0.02527895],
#        [0.02652171],
#        [0.02768743],
#        [0.02804418],
#        [0.02720506],
#        [0.02714812],
#        [0.02833728],
#        [0.02887994],
#        [0.02873087],
#        [0.02551008],
#        [0.02675787],
#        [0.02764053],
#        [0.02838418],
#        [0.02936733],
#        [0.02922664],
#        [0.02822506],
#        [0.02666743],
#        [0.02459728],
#        [0.02797551],
#        [0.02762713],
#        [0.02828871],
#        [0.02716654],
#        [0.02872585],
#        [0.03006743],
#        [0.03027009],
#        [0.03083285],
#        [0.02998034],
#        [0.0311829 ],
#        [0.03145255],
#        [0.03142576],
#        [0.03313246],
#        [0.03127669],
#        [0.02838083],
#        [0.02647314],
#        [0.02579314],
#        [0.02284703],
#        [0.0235823 ],
#        [0.01949894],
#        [0.02464082],
#        [0.02297264],
#        [0.02594388],
#        [0.02576467],
#        [0.02196604],
#        [0.02033136],
#        [0.02323392],
#        [0.02612644],
#        [0.02619176],
#        [0.02672437],
#        [0.02780299],
#        [0.02818654],
#        [0.02603265],
#        [0.02771255],
#        [0.02798388],
#        [0.02819491],
#        [0.02064959],
#        [0.02009017],
#        [0.01819254],
#        [0.01884909],
#        [0.0197753 ],
#        [0.01966476],
#        [0.01984564],
#        [0.02173993],
#        [0.02144683],
#        [0.02231609],
#        [0.02242998],
#        [0.02384693],
#        [0.02315521],
#        [0.0215289 ],
#        [0.02124249],
#        [0.02242161],
#        [0.02224909],
#        [0.02163944],
#        [0.02090249],
#        [0.02159087],
#        [0.02121569],
#        [0.02069984],
#        [0.01880219],
#        [0.01938505],
#        [0.02006505],
#        [0.01991264],
#        [0.02273984],
#        [0.02360072],
#        [0.01939845],
#        [0.01781904],
#        [0.0163418 ],
#        [0.01629155],
#        [0.01635017],
#        [0.01761471],
#        [0.01875027],
#        [0.01748407],
#        [0.018422  ],
#        [0.01858949],
#        [0.01615589],
#        [0.01516101],
#        [0.01482268],
#        [0.01584938],
#        [0.01591973],
#        [0.01433026],
#        [0.01364189],
#        [0.01487293],
#        [0.01605539],
#        [0.01669017],
#        [0.01689786],
#        [0.01845884],
#        [0.01790613],
#        [0.01889934],
#        [0.0148746 ],
#        [0.01607717],
#        [0.01578239],
#        [0.01563332],
#        [0.0162614 ],
#        [0.0149818 ],
#        [0.0148612 ],
#        [0.01464012],
#        [0.01580919],
#        [0.01545244],
#        [0.01579244],
#        [0.01403214],
#        [0.01422475],
#        [0.01334711],
#        [0.01149972],
#        [0.0094078 ],
#        [0.010468  ],
#        [0.01000238],
#        [0.00921854],
#        [0.01090849],
#        [0.01273913],
#        [0.01279105],
#        [0.01140425],
#        [0.01103243],
#        [0.01055341],
#        [0.01014139],
#        [0.00804612],
#        [0.00893381],
#        [0.00887351],
#        [0.0082672 ],
#        [0.00536966],
#        [0.00442001],
#        [0.00437311],
#        [0.00230464],
#        [0.0027669 ],
#        [0.00195291],
#        [0.00162966],
#        [0.00182394],
#        [0.00154926],
#        [0.00103675],
#        [0.        ],
#        [0.00245035],
#        [0.00295114],
#        [0.00451882],
#        [0.00427597],
#        [0.00567952],
#        [0.00638631],
#        [0.00507321],
#        [0.00585203],
#        [0.00602119],
#        [0.00771449],
#        [0.00766592],
#        [0.00794898],
#        [0.00680838],
#        [0.00718356],
#        [0.00748169],
#        [0.00683183],
#        [0.00674976],
#        [0.0073477 ],
#        [0.00745154],
#        [0.00807292],
#        [0.0076341 ],
#        [0.0093676 ],
#        [0.00906612],
#        [0.00860386],
#        [0.00855696],
#        [0.0100409 ],
#        [0.00998731],
#        [0.01107263],
#        [0.01248288],
#        [0.01229529],
#        [0.01271066],
#        [0.01248957],
#        [0.01326672],
#        [0.012848  ],
#        [0.01360002],
#        [0.01438889],
#        [0.00834927],
#        [0.00821863],
#        [0.00951331],
#        [0.01060031],
#        [0.01049144],
#        [0.00919174],
#        [0.00927381],
#        [0.00826553],
#        [0.00867252],
#        [0.00911972],
#        [0.00993706],
#        [0.00938602],
#        [0.0083811 ],
#        [0.00938435],
#        [0.00680838],
#        [0.00614178],
#        [0.00686198],
#        [0.00801597],
#        [0.00785351],
#        [0.00701104],
#        [0.00723213],
#        [0.00543163],
#        [0.00603459],
#        [0.0058805 ],
#        [0.00613341],
#        [0.00715844],
#        [0.00781164],
#        [0.00771115],
#        [0.00698592],
#        [0.00847656],
#        [0.00811981],
#        [0.00884671],
#        [0.00947479],
#        [0.01141095],
#        [0.01120494],
#        [0.01109272],
#        [0.01069243],
#        [0.01102405],
#        [0.01080632],
#        [0.01132721],
#        [0.01032563],
#        [0.0104278 ],
#        [0.00740967],
#        [0.00832918],
#        [0.01065056],
#        [0.01057854],
#        [0.01036751],
#        [0.01100731],
#        [0.01074603],
#        [0.0090544 ],
#        [0.00878642],
#        [0.00983992],
#        [0.01023016],
#        [0.01098051],
#        [0.01101568],
#        [0.01154327],
#        [0.01306238],
#        [0.01321815],
#        [0.01352968],
#        [0.0139015 ],
#        [0.01306071],
#        [0.01248288],
#        [0.01283125],
#        [0.01268051],
#        [0.02021747],
#        [0.0249825 ],
#        [0.02491216],
#        [0.02298772],
#        [0.02278506],
#        [0.02276998],
#        [0.02250033],
#        [0.02319708],
#        [0.02315521],
#        [0.02472289],
#        [0.02622358],
#        [0.02649156],
#        [0.0278231 ],
#        [0.02863374],
#        [0.02799393],
#        [0.02853659],
#        [0.02900891],
#        [0.02864378],
#        [0.03023994],
#        [0.02901728],
#        [0.02945442],
#        [0.02580486],
#        [0.02635757],
#        [0.02511481],
#        [0.02551176],
#        [0.02528565],
#        [0.02611137],
#        [0.02633413],
#        [0.02580319],
#        [0.02535767],
#        [0.02628221],
#        [0.02689186],
#        [0.02845118],
#        [0.02909767],
#        [0.03026674],
#        [0.03005069],
#        [0.03392132],
#        [0.03350094],
#        [0.03587256],
#        [0.03769651],
#        [0.03795611],
#        [0.04023897],
#        [0.04124892],
#        [0.04220193],
#        [0.04210814],
#        [0.03948193],
#        [0.04008991],
#        [0.04208804],
#        [0.04422351],
#        [0.04565218],
#        [0.04858657],
#        [0.05245219],
#        [0.05064332],
#        [0.05010904],
#        [0.05793239],
#        [0.06011978],
#        [0.05686717],
#        [0.05602806],
#        [0.05552727],
#        [0.06167408],
#        [0.06541911],
#        [0.06586127],
#        [0.06462521],
#        [0.06348629],
#        [0.06497358],
#        [0.06733349],
#        [0.07735263],
#        [0.0789873 ],
#        [0.10066526],
#        [0.11859652],
#        [0.09307806],
#        [0.09546644],
#        [0.09531738],
#        [0.09920477],
#        [0.09972398],
#        [0.09853649],
#        [0.10468497],
#        [0.10402005],
#        [0.11379631],
#        [0.12368145],
#        [0.120665  ],
#        [0.1209313 ],
#        [0.10967443],
#        [0.10399994],
#        [0.10046427],
#        [0.08374898],
#        [0.08190494],
#        [0.09457206],
#        [0.09488861],
#        [0.09555688],
#        [0.09137638],
#        [0.08784909],
#        [0.07185734],
#        [0.07810966],
#        [0.07625055],
#        [0.06391004],
#        [0.06157693],
#        [0.04456853],
#        [0.04207799],
#        [0.03052467],
#        [0.04164922],
#        [0.0416308 ],
#        [0.04276302],
#        [0.05460609],
#        [0.06034255],
#        [0.05848511],
#        [0.05617378],
#        [0.0541254 ],
#        [0.05778836],
#        [0.05068017],
#        [0.04614292],
#        [0.05042057],
#        [0.05648865],
#        [0.06138098],
#        [0.06194876],
#        [0.06599527],
#        [0.07905095],
#        [0.08892268],
#        [0.0922624 ],
#        [0.09483836],
#        [0.09629216],
#        [0.09503097],
#        [0.08504199],
#        [0.09264427],
#        [0.08820919],
#        [0.09147855],
#        [0.10380566],
#        [0.09884299],
#        [0.10410044],
#        [0.10098014],
#        [0.08748731],
#        [0.09751481],
#        [0.09869058],
#        [0.10109738],
#        [0.10067196],
#        [0.10726763],
#        [0.10590596],
#        [0.10559108],
#        [0.10250093],
#        [0.10457275],
#        [0.10387601],
#        [0.10629788],
#        [0.1053566 ],
#        [0.10662113],
#        [0.10863768],
#        [0.10684222],
#        [0.10717551],
#        [0.1074033 ],
#        [0.10498813],
#        [0.1098771 ],
#        [0.12044558],
#        [0.11767534],
#        [0.11790981],
#        [0.11479789],
#        [0.11836203],
#        [0.12912481],
#        [0.12757555],
#        [0.14170818],
#        [0.13296364],
#        [0.12667279],
#        [0.13598846],
#        [0.1345196 ],
#        [0.13613752],
#        [0.13817585],
#        [0.13766335],
#        [0.13656128],
#        [0.13781073],
#        [0.13095545],
#        [0.13516443],
#        [0.13076954],
#        [0.13907862],
#        [0.15087982],
#        [0.15754918],
#        [0.17246063],
#        [0.19974776],
#        [0.20280944],
#        [0.19879309],
#        [0.20354975],
#        [0.2287349 ],
#        [0.22076415],
#        [0.22407037],
#        [0.22896267],
#        [0.22136375],
#        [0.22139725],
#        [0.24520733],
#        [0.23270604],
#        [0.23672072],
#        [0.22344562],
#        [0.20735507],
#        [0.22788908],
#        [0.21731893],
#        [0.2211075 ],
#        [0.21916129],
#        [0.20965971],
#        [0.21874424],
#        [0.21907921],
#        [0.2187476 ],
#        [0.21951134],
#        [0.21333606],
#        [0.20761802],
#        [0.2002184 ],
#        [0.2304282 ],
#        [0.2415226 ],
#        [0.24649866],
#        [0.2774722 ],
#        [0.28608946],
#        [0.28465577],
#        [0.30530703],
#        [0.31337155],
#        [0.30737884],
#        [0.30890967],
#        [0.33065463],
#        [0.34498826],
#        [0.34074244],
#        [0.3873376 ],
#        [0.36785037],
#        [0.34467004],
#        [0.31086261],
#        [0.32034242],
#        [0.24655561],
#        [0.27676205],
#        [0.2809995 ],
#        [0.28215516],
#        [0.32143109],
#        [0.34667151],
#        [0.33997198],
#        [0.32462171],
#        [0.34029859],
#        [0.34636165],
#        [0.32529169],
#        [0.28855321],
#        [0.29477539],
#        [0.31114732],
#        [0.32275422],
#        [0.3209705 ],
#        [0.32929462],
#        [0.34533162],
#        [0.31763747],
#        [0.32650595],
#        [0.31670792],
#        [0.32618773],
#        [0.32670694],
#        [0.33347348],
#        [0.34042421],
#        [0.34406707],
#        [0.35633556],
#        [0.34593456],
#        [0.33822176],
#        [0.33081878],
#        [0.32337394],
#        [0.32396016],
#        [0.32659807],
#        [0.32227692],
#        [0.32198381],
#        [0.32566852],
#        [0.3100419 ],
#        [0.31406998],
#        [0.29498474],
#        [0.30542759],
#        [0.32501533],
#        [0.32256998],
#        [0.33689859],
#        [0.33008183],
#        [0.32280448],
#        [0.31367639],
#        [0.31934586],
#        [0.31484879],
#        [0.31211877],
#        [0.3117754 ],
#        [0.33984639],
#        [0.37755628],
#        [0.38813316],
#        [0.38004349],
#        [0.40704252],
#        [0.43512187],
#        [0.45071499],
#        [0.46056328],
#        [0.44535538],
#        [0.45972585],
#        [0.44637709],
#        [0.46694459],
#        [0.47168447],
#        [0.50745991],
#        [0.51425991],
#        [0.47624016],
#        [0.49515792],
#        [0.48085446],
#        [0.50584367],
#        [0.50033329],
#        [0.49155692],
#        [0.5193013 ],
#        [0.55204521],
#        [0.51424316],
#        [0.50627076],
#        [0.51099389],
#        [0.52421707],
#        [0.52582495],
#        [0.52775109],
#        [0.55186097],
#        [0.56098066],
#        [0.58116297],
#        [0.5856349 ],
#        [0.60311226],
#        [0.65340889],
#        [0.70698825],
#        [0.6493473 ],
#        [0.68137936],
#        [0.68554147],
#        [0.6776611 ],
#        [0.66188375],
#        [0.67728427],
#        [0.68222519],
#        [0.67765275],
#        [0.67903449],
#        [0.70764148],
#        [0.70955923],
#        [0.6937065 ],
#        [0.6696468 ],
#        [0.63455814],
#        [0.67331484],
#        [0.70093356],
#        [0.68577592],
#        [0.68183992],
#        [0.6837158 ],
#        [0.69308678],
#        [0.68139608],
#        [0.64401284],
#        [0.64974092],
#        [0.6534759 ],
#        [0.63681085],
#        [0.63842706],
#        [0.62940784],
#        [0.62431619],
#        [0.56837528],
#        [0.55526097],
#        [0.59142159],
#        [0.5413427 ],
#        [0.53571514],
#        [0.57166641],
#        [0.54487673],
#        [0.51704023],
#        [0.49044314],
#        [0.47077168],
#        [0.44150318],
#        [0.53410725],
#        [0.52948456],
#        [0.55589741],
#        [0.55098164],
#        [0.56288165],
#        [0.53687078],
#        [0.55774814],
#        [0.51700672],
#        [0.51843873],
#        [0.53110919],
#        [0.52454368],
#        [0.49783772],
#        [0.50631262],
#        [0.48815692],
#        [0.48194313],
#        [0.50231804],
#        [0.52937569],
#        [0.52420031],
#        [0.54873732],
#        [0.54921463],
#        [0.53192151],
#        [0.54266587],
#        [0.53698805],
#        [0.55789052],
#        [0.60842164],
#        [0.58322305],
#        [0.58876694],
#        [0.58954575],
#        [0.56848415],
#        [0.57213536],
#        [0.59318021],
#        [0.57272158],
#        [0.58085311],
#        [0.58822258],
#        [0.56020185],
#        [0.55154271],
#        [0.53697129],
#        [0.56413781],
#        [0.54358706],
#        [0.534124  ],
#        [0.5318964 ],
#        [0.52569933],
#        [0.53309395],
#        [0.49680766],
#        [0.4868924 ],
#        [0.46402193],
#        [0.44878053],
#        [0.46389631],
#        [0.45308497],
#        [0.45395591],
#        [0.44188841],
#        [0.46141749],
#        [0.45647658],
#        [0.47788155],
#        [0.47641604],
#        [0.48850864],
#        [0.49832346],
#        [0.49360865],
#        [0.49250322],
#        [0.47677612],
#        [0.44974359],
#        [0.47169287],
#        [0.47678452],
#        [0.47549485],
#        [0.47146677],
#        [0.48096333],
#        [0.4807707 ],
#        [0.48730274],
#        [0.47195247],
#        [0.47656677],
#        [0.48638995],
#        [0.49200916],
#        [0.48993229],
#        [0.49234413],
#        [0.51986241],
#        [0.53933288],
#        [0.53267521],
#        [0.54678608],
#        [0.54012005],
#        [0.53923237],
#        [0.53774171],
#        [0.53856242],
#        [0.52238309],
#        [0.50988011],
#        [0.51671362],
#        [0.52018063],
#        [0.544257  ],
#        [0.52988654],
#        [0.51719096],
#        [0.51486288],
#        [0.50952002],
#        [0.51119488],
#        [0.52315354],
#        [0.51879045],
#        [0.5137407 ],
#        [0.50881658],
#        [0.5207417 ],
#        [0.50998898],
#        [0.51183136],
#        [0.5372644 ],
#        [0.54551316],
#        [0.56433044],
#        [0.56438906],
#        [0.56537722],
#        [0.56848415],
#        [0.55547871],
#        [0.56775556],
#        [0.5645984 ],
#        [0.56278117],
#        [0.57486542],
#        [0.57061124],
#        [0.54465059],
#        [0.5275166 ],
#        [0.54701217],
#        [0.53401513],
#        [0.53970132],
#        [0.56150826],
#        [0.56334225],
#        [0.56561171],
#        [0.55720382],
#        [0.56621468],
#        [0.58211767],
#        [0.58614575],
#        [0.58478072],
#        [0.58335707],
#        [0.58434523],
#        [0.60054968],
#        [0.60134524],
#        [0.60217431],
#        [0.58660634],
#        [0.59224231],
#        [0.59349007],
#        [0.60298663],
#        [0.60395808],
#        [0.60605166],
#        [0.58149794],
#        [0.58921078],
#        [0.599729  ],
#        [0.60115265],
#        [0.61852953],
#        [0.63274091],
#        [0.62118423],
#        [0.62432463],
#        [0.61944237],
#        [0.61922462],
#        [0.62450887],
#        [0.62372162],
#        [0.62553049],
#        [0.63462515],
#        [0.62782507],
#        [0.63322661],
#        [0.64476651],
#        [0.64925514],
#        [0.65531827],
#        [0.6760114 ],
#        [0.69868928],
#        [0.69379858],
#        [0.69507989],
#        [0.71869567],
#        [0.73182669],
#        [0.828283  ],
#        [0.82289824],
#        [0.83916974],
#        [0.87198062],
#        [0.9029324 ],
#        [0.98214581],
#        [0.95150384],
#        [0.98655908],
#        [1.        ],
#        [0.99345124],
#        [0.94391667],
#        [0.82714407],
#        [0.86436829],
#        [0.86065003],
#        [0.83545148],
#        [0.81867757],
#        [0.85329732],
#        [0.88200474],
#        [0.88817667],
#        [0.92224371],
#        [0.93883338],
#        [0.8987703 ],
#        [0.90460726],
#        [0.87606735],
#        [0.92218513],
#        [0.92869203],
#        [0.88702102],
#        [0.87831163],
#        [0.82000074],
#        [0.8150096 ],
#        [0.85080179],
#        [0.86521412],
#        [0.81064655],
#        [0.82172589],
#        [0.77933465],
#        [0.77271888],
#        [0.78735731],
#        [0.74626417]])

# %%
x_train = []
y_train = [] 

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

# %%
#Convert the X_train and y_train to numpy arrays
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
#Reshape the data
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1)) #adding the batch_size axis
x_train.shape
# Out:
# (779, 100, 1)

# %%
#Model building(LSTM)
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu' , return_sequences=False ))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# C:\Users\ghosh\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compile the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
#Train the model
history= model.fit(x_train, y_train,epochs = 100,batch_size = 32)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - loss: 0.0979 - mean_absolute_error: 0.2233
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - loss: 0.0125 - mean_absolute_error: 0.0790
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - loss: 0.0089 - mean_absolute_error: 0.0617
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - loss: 0.0069 - mean_absolute_error: 0.0545
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - loss: 0.0065 - mean_absolute_error: 0.0512
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - loss: 0.0068 - mean_absolute_error: 0.0517
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - loss: 0.0066 - mean_absolute_error: 0.0497
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - loss: 0.0062 - mean_absolute_error: 0.0467
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - loss: 0.0069 - mean_absolute_error: 0.0527
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - loss: 0.0061 - mean_absolute_error: 0.0501
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - loss: 0.0064 - mean_absolute_error: 0.0511
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - loss: 0.0071 - mean_absolute_error: 0.0518
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - loss: 0.0074 - mean_absolute_error: 0.0516
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - loss: 0.0049 - mean_absolute_error: 0.0452
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - loss: 0.0050 - mean_absolute_error: 0.0449
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - loss: 0.0048 - mean_absolute_error: 0.0420
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - loss: 0.0049 - mean_absolute_error: 0.0424
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - loss: 0.0044 - mean_absolute_error: 0.0428
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 231ms/step - loss: 0.0048 - mean_absolute_error: 0.0433
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 255ms/step - loss: 0.0050 - mean_absolute_error: 0.0444
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - loss: 0.0038 - mean_absolute_error: 0.0392
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - loss: 0.0038 - mean_absolute_error: 0.0418
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - loss: 0.0043 - mean_absolute_error: 0.0411
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - loss: 0.0053 - mean_absolute_error: 0.0463
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - loss: 0.0043 - mean_absolute_error: 0.0413
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - loss: 0.0034 - mean_absolute_error: 0.0375
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - loss: 0.0052 - mean_absolute_error: 0.0450
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - loss: 0.0040 - mean_absolute_error: 0.0403
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - loss: 0.0038 - mean_absolute_error: 0.0395
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 256ms/step - loss: 0.0059 - mean_absolute_error: 0.0504
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - loss: 0.0053 - mean_absolute_error: 0.0487
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - loss: 0.0048 - mean_absolute_error: 0.0473
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 252ms/step - loss: 0.0040 - mean_absolute_error: 0.0409
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - loss: 0.0052 - mean_absolute_error: 0.0464
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - loss: 0.0043 - mean_absolute_error: 0.0431
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - loss: 0.0047 - mean_absolute_error: 0.0437
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - loss: 0.0039 - mean_absolute_error: 0.0398
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - loss: 0.0035 - mean_absolute_error: 0.0396
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 249ms/step - loss: 0.0034 - mean_absolute_error: 0.0396
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - loss: 0.0036 - mean_absolute_error: 0.0388
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - loss: 0.0059 - mean_absolute_error: 0.0487
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 253ms/step - loss: 0.0042 - mean_absolute_error: 0.0435
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - loss: 0.0052 - mean_absolute_error: 0.0443
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - loss: 0.0036 - mean_absolute_error: 0.0385
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - loss: 0.0034 - mean_absolute_error: 0.0387
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.0036 - mean_absolute_error: 0.0402
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0035 - mean_absolute_error: 0.0382
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0038 - mean_absolute_error: 0.0393
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0038 - mean_absolute_error: 0.0406
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0030 - mean_absolute_error: 0.0363
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0038 - mean_absolute_error: 0.0434
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0036 - mean_absolute_error: 0.0379
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0039 - mean_absolute_error: 0.0403
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0039 - mean_absolute_error: 0.0422
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0032 - mean_absolute_error: 0.0380
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0051 - mean_absolute_error: 0.0463
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0036 - mean_absolute_error: 0.0390
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0039 - mean_absolute_error: 0.0419
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0035 - mean_absolute_error: 0.0401
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0032 - mean_absolute_error: 0.0383
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0037 - mean_absolute_error: 0.0408
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0030 - mean_absolute_error: 0.0368
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0028 - mean_absolute_error: 0.0367
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0033 - mean_absolute_error: 0.0395
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0037 - mean_absolute_error: 0.0393
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0035 - mean_absolute_error: 0.0403
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0034 - mean_absolute_error: 0.0400
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0029 - mean_absolute_error: 0.0388
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0030 - mean_absolute_error: 0.0375
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0042 - mean_absolute_error: 0.0415
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0039 - mean_absolute_error: 0.0421
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0031 - mean_absolute_error: 0.0376
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0031 - mean_absolute_error: 0.0391
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0032 - mean_absolute_error: 0.0396
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0035 - mean_absolute_error: 0.0400
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.0034 - mean_absolute_error: 0.0389
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0032 - mean_absolute_error: 0.0384
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0030 - mean_absolute_error: 0.0379
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0028 - mean_absolute_error: 0.0373
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0037 - mean_absolute_error: 0.0409
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0025 - mean_absolute_error: 0.0353
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0030 - mean_absolute_error: 0.0376
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0028 - mean_absolute_error: 0.0379
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0030 - mean_absolute_error: 0.0382
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - loss: 0.0032 - mean_absolute_error: 0.0388
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.0033 - mean_absolute_error: 0.0402
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0028 - mean_absolute_error: 0.0368
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0028 - mean_absolute_error: 0.0379
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0024 - mean_absolute_error: 0.0364
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0034 - mean_absolute_error: 0.0411
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0028 - mean_absolute_error: 0.0370
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0030 - mean_absolute_error: 0.0392
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0029 - mean_absolute_error: 0.0377
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0032 - mean_absolute_error: 0.0380
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0038 - mean_absolute_error: 0.0430
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - loss: 0.0029 - mean_absolute_error: 0.0377
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.0042 - mean_absolute_error: 0.0445
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0038 - mean_absolute_error: 0.0433
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.0028 - mean_absolute_error: 0.0380
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0027 - mean_absolute_error: 0.0379

# %%
loss = history.history['loss']
epochs = range(len(loss))
plt.plot(epochs, loss, 'b', label='Training loss')
plt.title('Training loss', size=15, weight='bold')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
model.save('my_model.keras')

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %%
#Defining the final dataset for testing by including last 100 coloums of the training dataset to get the prediction from the 1st column of the testing dataset.
final_data = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_data.head()
# Out:
#             0
# 0  215.660004
# 1  225.783340
# 2  229.066666
# 3  236.556671
# 4  236.580002

# %%
input_data = scaler.fit_transform(final_data)
input_data
# Out:
# array([[0.35631234],
#        [0.38984775],
#        [0.40072437],
#        [0.4255364 ],
#        [0.42561368],
#        [0.42691665],
#        [0.43101338],
#        [0.41386471],
#        [0.43005267],
#        [0.42588972],
#        [0.42349357],
#        [0.43942757],
#        [0.43381811],
#        [0.399587  ],
#        [0.37699452],
#        [0.40270093],
#        [0.38556334],
#        [0.39306101],
#        [0.42181513],
#        [0.42423338],
#        [0.42722585],
#        [0.4161394 ],
#        [0.42802091],
#        [0.44899021],
#        [0.45430154],
#        [0.45250165],
#        [0.45062446],
#        [0.45192742],
#        [0.47329423],
#        [0.47434324],
#        [0.47543643],
#        [0.45490887],
#        [0.46234032],
#        [0.46398559],
#        [0.47650753],
#        [0.47778846],
#        [0.48054901],
#        [0.44817305],
#        [0.45834302],
#        [0.4722121 ],
#        [0.47408929],
#        [0.49700204],
#        [0.51574082],
#        [0.50050246],
#        [0.50464331],
#        [0.49820568],
#        [0.49791857],
#        [0.50488624],
#        [0.5038482 ],
#        [0.50623333],
#        [0.51822534],
#        [0.50925891],
#        [0.51638126],
#        [0.53159749],
#        [0.5375161 ],
#        [0.5455108 ],
#        [0.57279627],
#        [0.60269878],
#        [0.59625003],
#        [0.59793953],
#        [0.62907874],
#        [0.646393  ],
#        [0.77357801],
#        [0.7664778 ],
#        [0.78793301],
#        [0.83119666],
#        [0.87200896],
#        [0.97645788],
#        [0.93605411],
#        [0.98227712],
#        [1.        ],
#        [0.99136496],
#        [0.92604984],
#        [0.77207624],
#        [0.82115923],
#        [0.81625642],
#        [0.7830302 ],
#        [0.76091251],
#        [0.8065613 ],
#        [0.84441424],
#        [0.85255239],
#        [0.89747238],
#        [0.91934714],
#        [0.8665209 ],
#        [0.87421738],
#        [0.83658533],
#        [0.89739515],
#        [0.90597499],
#        [0.85102859],
#        [0.83954459],
#        [0.76265722],
#        [0.75607603],
#        [0.80327076],
#        [0.82227451],
#        [0.75032301],
#        [0.76493196],
#        [0.70903587],
#        [0.70031247],
#        [0.71961436],
#        [0.66542991],
#        [0.67166879],
#        [0.63563789],
#        [0.67824998],
#        [0.75592145],
#        [0.82011017],
#        [0.84985811],
#        [0.84381798],
#        [0.84130031],
#        [0.82379832],
#        [0.80882502],
#        [0.9667296 ],
#        [0.91130836],
#        [0.84343149],
#        [0.81757046],
#        [0.77589693],
#        [0.81030465],
#        [0.81723917],
#        [0.86341799],
#        [0.78097636],
#        [0.80090766],
#        [0.77981689],
#        [0.74132352],
#        [0.74200814],
#        [0.68417972],
#        [0.66883095],
#        [0.6560219 ],
#        [0.67701329],
#        [0.55741435],
#        [0.57646228],
#        [0.67625133],
#        [0.6702112 ],
#        [0.64195401],
#        [0.62592063],
#        [0.66145475],
#        [0.64380911],
#        [0.65999716],
#        [0.67103937],
#        [0.64072834],
#        [0.59153495],
#        [0.60893767],
#        [0.66047191],
#        [0.66153199],
#        [0.60958913],
#        [0.58820023],
#        [0.5490553 ],
#        [0.48557324],
#        [0.52613158],
#        [0.53618003],
#        [0.60305211],
#        [0.59636043],
#        [0.61349807],
#        [0.56866643],
#        [0.56756217],
#        [0.53033865],
#        [0.55222443],
#        [0.59039764],
#        [0.56757319],
#        [0.52014665],
#        [0.48814611],
#        [0.52736828],
#        [0.56970438],
#        [0.60434401],
#        [0.64165588],
#        [0.65906962],
#        [0.73947944],
#        [0.74514421],
#        [0.76149776],
#        [0.75787592],
#        [0.84753919],
#        [0.85607495],
#        [0.84991331],
#        [0.83181506],
#        [0.83953357],
#        [0.90673694],
#        [0.84689875],
#        [0.79665641],
#        [0.80935506],
#        [0.77427365],
#        [0.71954814],
#        [0.73171675],
#        [0.77082853],
#        [0.72956353],
#        [0.75086407],
#        [0.77721097],
#        [0.72095053],
#        [0.75582207],
#        [0.75170326],
#        [0.74394057],
#        [0.60966646],
#        [0.61528695],
#        [0.61087   ],
#        [0.60341646],
#        [0.63895058],
#        [0.64591826],
#        [0.69380862],
#        [0.6061991 ],
#        [0.59777384],
#        [0.51104779],
#        [0.52532545],
#        [0.45240227],
#        [0.4457769 ],
#        [0.49170172],
#        [0.44176853],
#        [0.48288997],
#        [0.42569097],
#        [0.42526031],
#        [0.37499587],
#        [0.38714235],
#        [0.33553077],
#        [0.36936432],
#        [0.42339419],
#        [0.48070364],
#        [0.4791908 ],
#        [0.45943616],
#        [0.49767564],
#        [0.41877849],
#        [0.43124524],
#        [0.43325496],
#        [0.44312674],
#        [0.43597133],
#        [0.41120349],
#        [0.35656629],
#        [0.37363766],
#        [0.41375427],
#        [0.34783187],
#        [0.35995626],
#        [0.42712647],
#        [0.42397943],
#        [0.42061155],
#        [0.45584744],
#        [0.45324146],
#        [0.41263899],
#        [0.39881408],
#        [0.3855081 ],
#        [0.39475051],
#        [0.41397511],
#        [0.40955821],
#        [0.45199369],
#        [0.47259859],
#        [0.41820432],
#        [0.41398618],
#        [0.42713749],
#        [0.43135568],
#        [0.4371639 ],
#        [0.43875397],
#        [0.4552622 ],
#        [0.46178819],
#        [0.54197723],
#        [0.54375508],
#        [0.53113366],
#        [0.49942023],
#        [0.55229075],
#        [0.57243182],
#        [0.62626294],
#        [0.62668259],
#        [0.63764756],
#        [0.66020693],
#        [0.66430361],
#        [0.5965151 ],
#        [0.60397966],
#        [0.58049274],
#        [0.6170095 ],
#        [0.59141354],
#        [0.63580349],
#        [0.66657835],
#        [0.65744633],
#        [0.64894383],
#        [0.6452115 ],
#        [0.6246618 ],
#        [0.60229016],
#        [0.62395514],
#        [0.62608633],
#        [0.62268529],
#        [0.59625003],
#        [0.58541759],
#        [0.56183129],
#        [0.55490769],
#        [0.56004242],
#        [0.53701922],
#        [0.55096569],
#        [0.5817074 ],
#        [0.60012592],
#        [0.63464403],
#        [0.65034622],
#        [0.6096333 ],
#        [0.64435017],
#        [0.64812668],
#        [0.64680162],
#        [0.66575018],
#        [0.66462388],
#        [0.63835422],
#        [0.59790637],
#        [0.55398015],
#        [0.55623285],
#        [0.57918972],
#        [0.59532248],
#        [0.53039385],
#        [0.52058833],
#        [0.44489348],
#        [0.4682148 ],
#        [0.43962632],
#        [0.43074835],
#        [0.38085934],
#        [0.38049494],
#        [0.35909498],
#        [0.36154638],
#        [0.37638719],
#        [0.320966  ],
#        [0.36853615],
#        [0.37131879],
#        [0.37744723],
#        [0.32855203],
#        [0.35227085],
#        [0.34170339],
#        [0.37870606],
#        [0.38606022],
#        [0.38755092],
#        [0.39891346],
#        [0.39566699],
#        [0.39659459],
#        [0.35405968],
#        [0.35515288],
#        [0.32918144],
#        [0.29476266],
#        [0.27561534],
#        [0.23019842],
#        [0.27369398],
#        [0.29108557],
#        [0.27445589],
#        [0.2859509 ],
#        [0.26110577],
#        [0.24868321],
#        [0.23881142],
#        [0.19799913],
#        [0.20475703],
#        [0.24878258],
#        [0.24765628],
#        [0.24785503],
#        [0.24093154],
#        [0.28687845],
#        [0.28687845],
#        [0.28740849],
#        [0.24629807],
#        [0.23758574],
#        [0.21843838],
#        [0.2164508 ],
#        [0.23503496],
#        [0.19783353],
#        [0.17507536],
#        [0.16132774],
#        [0.16420976],
#        [0.13956338],
#        [0.13837081],
#        [0.09838674],
#        [0.09762483],
#        [0.0571438 ],
#        [0.04985591],
#        [0.00331268],
#        [0.01527148],
#        [0.04545003],
#        [0.04995528],
#        [0.        ],
#        [0.01835227],
#        [0.00742041],
#        [0.01643091],
#        [0.03865902],
#        [0.03561136],
#        [0.0500878 ],
#        [0.0512141 ],
#        [0.0473714 ],
#        [0.07748371],
#        [0.06850631],
#        [0.06317289],
#        [0.08387716],
#        [0.1180972 ],
#        [0.11856097],
#        [0.1203498 ],
#        [0.17282276],
#        [0.23122535],
#        [0.19399081],
#        [0.21572201],
#        [0.2428529 ],
#        [0.26557792],
#        [0.27124258],
#        [0.28707721],
#        [0.29386822],
#        [0.30870903],
#        [0.32868456],
#        [0.29413324],
#        [0.2866797 ],
#        [0.33507802],
#        [0.35160833],
#        [0.31119354],
#        [0.33196409],
#        [0.29572331],
#        [0.3072846 ],
#        [0.31129297],
#        [0.29410013],
#        [0.32971149],
#        [0.32335114],
#        [0.31361184],
#        [0.27429024],
#        [0.29711463],
#        [0.28393017],
#        [0.26372282],
#        [0.24480737],
#        [0.21472819],
#        [0.2164508 ],
#        [0.21989597],
#        [0.24898134],
#        [0.2396727 ],
#        [0.25186341],
#        [0.23861267],
#        [0.24894823],
#        [0.296419  ],
#        [0.27511841],
#        [0.27866301],
#        [0.27266706],
#        [0.2773048 ],
#        [0.26862558],
#        [0.28416208],
#        [0.28879981],
#        [0.32914834],
#        [0.28711036],
#        [0.27985558],
#        [0.25646803],
#        [0.25494418],
#        [0.25312219],
#        [0.26067511],
#        [0.23997083],
#        [0.25772682],
#        [0.25474542],
#        [0.26150328],
#        [0.25245967],
#        [0.24013647],
#        [0.18183326],
#        [0.18875676],
#        [0.18037567],
#        [0.17414781],
#        [0.15122404],
#        [0.17255774],
#        [0.18620598],
#        [0.17799054],
#        [0.17295524],
#        [0.17394906],
#        [0.17590353],
#        [0.20525392],
#        [0.21098484],
#        [0.20223936],
#        [0.20021862],
#        [0.21194555],
#        [0.19836353],
#        [0.19296388],
#        [0.19352703],
#        [0.21784213],
#        [0.22787955],
#        [0.23864578],
#        [0.2675655 ],
#        [0.2572962 ],
#        [0.24778877],
#        [0.2529897 ],
#        [0.28181005],
#        [0.30827841],
#        [0.31745451],
#        [0.32934709],
#        [0.35071389],
#        [0.36277206],
#        [0.37502898],
#        [0.38582836],
#        [0.41991586],
#        [0.45151885],
#        [0.46950675],
#        [0.49892335],
#        [0.49256306],
#        [0.48961472],
#        [0.50498562],
#        [0.55106507],
#        [0.50140786]])

# %%
input_data.shape
# Out:
# (478, 1)

# %%
#Testing the model
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (378, 100, 1)
# (378,)

# %%
#Making prediction and plotting the graph of predicted vs actual values
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step

# %%
y_pred.shape
# Out:
# (378, 1)

# %%
y_test
# Out:
# array([0.67166879, 0.63563789, 0.67824998, 0.75592145, 0.82011017,
#        0.84985811, 0.84381798, 0.84130031, 0.82379832, 0.80882502,
#        0.9667296 , 0.91130836, 0.84343149, 0.81757046, 0.77589693,
#        0.81030465, 0.81723917, 0.86341799, 0.78097636, 0.80090766,
#        0.77981689, 0.74132352, 0.74200814, 0.68417972, 0.66883095,
#        0.6560219 , 0.67701329, 0.55741435, 0.57646228, 0.67625133,
#        0.6702112 , 0.64195401, 0.62592063, 0.66145475, 0.64380911,
#        0.65999716, 0.67103937, 0.64072834, 0.59153495, 0.60893767,
#        0.66047191, 0.66153199, 0.60958913, 0.58820023, 0.5490553 ,
#        0.48557324, 0.52613158, 0.53618003, 0.60305211, 0.59636043,
#        0.61349807, 0.56866643, 0.56756217, 0.53033865, 0.55222443,
#        0.59039764, 0.56757319, 0.52014665, 0.48814611, 0.52736828,
#        0.56970438, 0.60434401, 0.64165588, 0.65906962, 0.73947944,
#        0.74514421, 0.76149776, 0.75787592, 0.84753919, 0.85607495,
#        0.84991331, 0.83181506, 0.83953357, 0.90673694, 0.84689875,
#        0.79665641, 0.80935506, 0.77427365, 0.71954814, 0.73171675,
#        0.77082853, 0.72956353, 0.75086407, 0.77721097, 0.72095053,
#        0.75582207, 0.75170326, 0.74394057, 0.60966646, 0.61528695,
#        0.61087   , 0.60341646, 0.63895058, 0.64591826, 0.69380862,
#        0.6061991 , 0.59777384, 0.51104779, 0.52532545, 0.45240227,
#        0.4457769 , 0.49170172, 0.44176853, 0.48288997, 0.42569097,
#        0.42526031, 0.37499587, 0.38714235, 0.33553077, 0.36936432,
#        0.42339419, 0.48070364, 0.4791908 , 0.45943616, 0.49767564,
#        0.41877849, 0.43124524, 0.43325496, 0.44312674, 0.43597133,
#        0.41120349, 0.35656629, 0.37363766, 0.41375427, 0.34783187,
#        0.35995626, 0.42712647, 0.42397943, 0.42061155, 0.45584744,
#        0.45324146, 0.41263899, 0.39881408, 0.3855081 , 0.39475051,
#        0.41397511, 0.40955821, 0.45199369, 0.47259859, 0.41820432,
#        0.41398618, 0.42713749, 0.43135568, 0.4371639 , 0.43875397,
#        0.4552622 , 0.46178819, 0.54197723, 0.54375508, 0.53113366,
#        0.49942023, 0.55229075, 0.57243182, 0.62626294, 0.62668259,
#        0.63764756, 0.66020693, 0.66430361, 0.5965151 , 0.60397966,
#        0.58049274, 0.6170095 , 0.59141354, 0.63580349, 0.66657835,
#        0.65744633, 0.64894383, 0.6452115 , 0.6246618 , 0.60229016,
#        0.62395514, 0.62608633, 0.62268529, 0.59625003, 0.58541759,
#        0.56183129, 0.55490769, 0.56004242, 0.53701922, 0.55096569,
#        0.5817074 , 0.60012592, 0.63464403, 0.65034622, 0.6096333 ,
#        0.64435017, 0.64812668, 0.64680162, 0.66575018, 0.66462388,
#        0.63835422, 0.59790637, 0.55398015, 0.55623285, 0.57918972,
#        0.59532248, 0.53039385, 0.52058833, 0.44489348, 0.4682148 ,
#        0.43962632, 0.43074835, 0.38085934, 0.38049494, 0.35909498,
#        0.36154638, 0.37638719, 0.320966  , 0.36853615, 0.37131879,
#        0.37744723, 0.32855203, 0.35227085, 0.34170339, 0.37870606,
#        0.38606022, 0.38755092, 0.39891346, 0.39566699, 0.39659459,
#        0.35405968, 0.35515288, 0.32918144, 0.29476266, 0.27561534,
#        0.23019842, 0.27369398, 0.29108557, 0.27445589, 0.2859509 ,
#        0.26110577, 0.24868321, 0.23881142, 0.19799913, 0.20475703,
#        0.24878258, 0.24765628, 0.24785503, 0.24093154, 0.28687845,
#        0.28687845, 0.28740849, 0.24629807, 0.23758574, 0.21843838,
#        0.2164508 , 0.23503496, 0.19783353, 0.17507536, 0.16132774,
#        0.16420976, 0.13956338, 0.13837081, 0.09838674, 0.09762483,
#        0.0571438 , 0.04985591, 0.00331268, 0.01527148, 0.04545003,
#        0.04995528, 0.        , 0.01835227, 0.00742041, 0.01643091,
#        0.03865902, 0.03561136, 0.0500878 , 0.0512141 , 0.0473714 ,
#        0.07748371, 0.06850631, 0.06317289, 0.08387716, 0.1180972 ,
#        0.11856097, 0.1203498 , 0.17282276, 0.23122535, 0.19399081,
#        0.21572201, 0.2428529 , 0.26557792, 0.27124258, 0.28707721,
#        0.29386822, 0.30870903, 0.32868456, 0.29413324, 0.2866797 ,
#        0.33507802, 0.35160833, 0.31119354, 0.33196409, 0.29572331,
#        0.3072846 , 0.31129297, 0.29410013, 0.32971149, 0.32335114,
#        0.31361184, 0.27429024, 0.29711463, 0.28393017, 0.26372282,
#        0.24480737, 0.21472819, 0.2164508 , 0.21989597, 0.24898134,
#        0.2396727 , 0.25186341, 0.23861267, 0.24894823, 0.296419  ,
#        0.27511841, 0.27866301, 0.27266706, 0.2773048 , 0.26862558,
#        0.28416208, 0.28879981, 0.32914834, 0.28711036, 0.27985558,
#        0.25646803, 0.25494418, 0.25312219, 0.26067511, 0.23997083,
#        0.25772682, 0.25474542, 0.26150328, 0.25245967, 0.24013647,
#        0.18183326, 0.18875676, 0.18037567, 0.17414781, 0.15122404,
#        0.17255774, 0.18620598, 0.17799054, 0.17295524, 0.17394906,
#        0.17590353, 0.20525392, 0.21098484, 0.20223936, 0.20021862,
#        0.21194555, 0.19836353, 0.19296388, 0.19352703, 0.21784213,
#        0.22787955, 0.23864578, 0.2675655 , 0.2572962 , 0.24778877,
#        0.2529897 , 0.28181005, 0.30827841, 0.31745451, 0.32934709,
#        0.35071389, 0.36277206, 0.37502898, 0.38582836, 0.41991586,
#        0.45151885, 0.46950675, 0.49892335, 0.49256306, 0.48961472,
#        0.50498562, 0.55106507, 0.50140786])

# %%
y_pred
# Out:
# array([[0.70501333],
#        [0.6897674 ],
#        [0.67390454],
#        [0.6593207 ],
#        [0.65086794],
#        [0.65386504],
#        [0.6706739 ],
#        [0.698285  ],
#        [0.7306981 ],
#        [0.7604776 ],
#        [0.78264356],
#        [0.80467665],
#        [0.82519495],
#        [0.83893687],
#        [0.8436668 ],
#        [0.83883417],
#        [0.8291091 ],
#        [0.8177349 ],
#        [0.80895567],
#        [0.80034345],
#        [0.7921612 ],
#        [0.783691  ],
#        [0.77342975],
#        [0.76166594],
#        [0.747123  ],
#        [0.72978675],
#        [0.7103023 ],
#        [0.69069374],
#        [0.6693859 ],
#        [0.6468343 ],
#        [0.62622947],
#        [0.6108999 ],
#        [0.6018623 ],
#        [0.5977478 ],
#        [0.598635  ],
#        [0.60294545],
#        [0.6098348 ],
#        [0.6188097 ],
#        [0.6272868 ],
#        [0.6314579 ],
#        [0.6310778 ],
#        [0.62941086],
#        [0.6287242 ],
#        [0.62758404],
#        [0.62419426],
#        [0.616778  ],
#        [0.6041238 ],
#        [0.5880337 ],
#        [0.5705973 ],
#        [0.5553538 ],
#        [0.54519814],
#        [0.5423262 ],
#        [0.5445476 ],
#        [0.5491578 ],
#        [0.5524839 ],
#        [0.5537637 ],
#        [0.5549097 ],
#        [0.5562045 ],
#        [0.5555939 ],
#        [0.55133545],
#        [0.5446747 ],
#        [0.53849214],
#        [0.53624576],
#        [0.5410204 ],
#        [0.5538748 ],
#        [0.5767824 ],
#        [0.6085217 ],
#        [0.64562666],
#        [0.6827106 ],
#        [0.71966755],
#        [0.75497246],
#        [0.7856394 ],
#        [0.80828667],
#        [0.823158  ],
#        [0.8349734 ],
#        [0.8420282 ],
#        [0.84186053],
#        [0.8362226 ],
#        [0.8258333 ],
#        [0.8104515 ],
#        [0.79163414],
#        [0.77278084],
#        [0.754698  ],
#        [0.7390944 ],
#        [0.728161  ],
#        [0.7201734 ],
#        [0.7154334 ],
#        [0.71350396],
#        [0.71337116],
#        [0.70795536],
#        [0.6965329 ],
#        [0.68019235],
#        [0.66078025],
#        [0.6411685 ],
#        [0.6240717 ],
#        [0.6133524 ],
#        [0.6069693 ],
#        [0.60234267],
#        [0.5947669 ],
#        [0.58382314],
#        [0.5691093 ],
#        [0.5512713 ],
#        [0.53220546],
#        [0.51293206],
#        [0.4949715 ],
#        [0.47855377],
#        [0.46374226],
#        [0.44985586],
#        [0.43674767],
#        [0.42409372],
#        [0.41203344],
#        [0.40137243],
#        [0.3941586 ],
#        [0.39251447],
#        [0.39636856],
#        [0.40553477],
#        [0.4161982 ],
#        [0.42569357],
#        [0.43279952],
#        [0.43759358],
#        [0.44034445],
#        [0.44073105],
#        [0.437595  ],
#        [0.43149263],
#        [0.42402375],
#        [0.41549933],
#        [0.406442  ],
#        [0.39830598],
#        [0.39251524],
#        [0.38989735],
#        [0.39117002],
#        [0.39622116],
#        [0.40289497],
#        [0.4089194 ],
#        [0.41255575],
#        [0.41348916],
#        [0.4127236 ],
#        [0.41116518],
#        [0.4106307 ],
#        [0.41264844],
#        [0.41607034],
#        [0.41947728],
#        [0.42233104],
#        [0.424605  ],
#        [0.42657608],
#        [0.42849195],
#        [0.4309529 ],
#        [0.4344222 ],
#        [0.44128096],
#        [0.45256335],
#        [0.46741706],
#        [0.48262835],
#        [0.49780947],
#        [0.51339096],
#        [0.5313404 ],
#        [0.55188936],
#        [0.57417464],
#        [0.5973946 ],
#        [0.6200507 ],
#        [0.636547  ],
#        [0.64521605],
#        [0.64584583],
#        [0.6415002 ],
#        [0.6337499 ],
#        [0.62589735],
#        [0.62130105],
#        [0.62090653],
#        [0.6237581 ],
#        [0.6281127 ],
#        [0.63160455],
#        [0.6321086 ],
#        [0.6301611 ],
#        [0.6268276 ],
#        [0.62292147],
#        [0.617918  ],
#        [0.6113729 ],
#        [0.6027722 ],
#        [0.59232956],
#        [0.58095497],
#        [0.5690427 ],
#        [0.5576235 ],
#        [0.5486436 ],
#        [0.5442485 ],
#        [0.5466351 ],
#        [0.55648863],
#        [0.5703364 ],
#        [0.5864162 ],
#        [0.60305053],
#        [0.61851454],
#        [0.63251334],
#        [0.64455557],
#        [0.65284264],
#        [0.6551304 ],
#        [0.64979655],
#        [0.638342  ],
#        [0.6234423 ],
#        [0.6080507 ],
#        [0.59222865],
#        [0.5761063 ],
#        [0.5587721 ],
#        [0.54053354],
#        [0.5216959 ],
#        [0.502802  ],
#        [0.48392206],
#        [0.465487  ],
#        [0.4478112 ],
#        [0.43118495],
#        [0.41597164],
#        [0.40207988],
#        [0.38973022],
#        [0.37916753],
#        [0.3707289 ],
#        [0.3639689 ],
#        [0.3586458 ],
#        [0.35443446],
#        [0.351563  ],
#        [0.3504405 ],
#        [0.3513146 ],
#        [0.35439476],
#        [0.35929802],
#        [0.3653697 ],
#        [0.37069964],
#        [0.37409192],
#        [0.37477928],
#        [0.37260795],
#        [0.36807975],
#        [0.36173785],
#        [0.35431272],
#        [0.34650233],
#        [0.33880496],
#        [0.33160105],
#        [0.3250373 ],
#        [0.3191052 ],
#        [0.3137003 ],
#        [0.30860466],
#        [0.30368266],
#        [0.29902375],
#        [0.2947517 ],
#        [0.2909801 ],
#        [0.2877478 ],
#        [0.2852305 ],
#        [0.28357673],
#        [0.2828269 ],
#        [0.28267893],
#        [0.28276354],
#        [0.28272438],
#        [0.28233784],
#        [0.28161132],
#        [0.2804975 ],
#        [0.27892458],
#        [0.27685913],
#        [0.27434367],
#        [0.27141562],
#        [0.26813668],
#        [0.2644845 ],
#        [0.26049164],
#        [0.2560859 ],
#        [0.25066128],
#        [0.24302869],
#        [0.23250902],
#        [0.21863814],
#        [0.20184931],
#        [0.18284766],
#        [0.16431797],
#        [0.14561778],
#        [0.1265239 ],
#        [0.10828386],
#        [0.09174197],
#        [0.07739802],
#        [0.06547038],
#        [0.05594689],
#        [0.04873921],
#        [0.04377021],
#        [0.04096182],
#        [0.04028556],
#        [0.04175332],
#        [0.04529923],
#        [0.05086329],
#        [0.05841536],
#        [0.06789148],
#        [0.0786138 ],
#        [0.09005064],
#        [0.10201588],
#        [0.11463211],
#        [0.12817596],
#        [0.1425748 ],
#        [0.15773804],
#        [0.17341815],
#        [0.18953156],
#        [0.20533946],
#        [0.22001739],
#        [0.23353763],
#        [0.24634461],
#        [0.25822   ],
#        [0.26909268],
#        [0.2784197 ],
#        [0.2860602 ],
#        [0.29213873],
#        [0.29672974],
#        [0.30030495],
#        [0.30324322],
#        [0.30571067],
#        [0.30744278],
#        [0.30844986],
#        [0.3087638 ],
#        [0.30838865],
#        [0.30731368],
#        [0.30548704],
#        [0.30298418],
#        [0.29995447],
#        [0.2966678 ],
#        [0.29335088],
#        [0.29022133],
#        [0.28739405],
#        [0.28495473],
#        [0.28314143],
#        [0.28204364],
#        [0.28165078],
#        [0.2818365 ],
#        [0.28245652],
#        [0.28332067],
#        [0.28434992],
#        [0.28552195],
#        [0.2871288 ],
#        [0.28903016],
#        [0.29093063],
#        [0.29244846],
#        [0.2933869 ],
#        [0.2937029 ],
#        [0.29348737],
#        [0.29278597],
#        [0.2917527 ],
#        [0.29053366],
#        [0.2892784 ],
#        [0.28806308],
#        [0.28687137],
#        [0.2854569 ],
#        [0.28367656],
#        [0.28148824],
#        [0.2789039 ],
#        [0.27593997],
#        [0.2727076 ],
#        [0.269369  ],
#        [0.2660407 ],
#        [0.26279804],
#        [0.2597091 ],
#        [0.2568218 ],
#        [0.2542402 ],
#        [0.2520659 ],
#        [0.2503494 ],
#        [0.24906877],
#        [0.24820514],
#        [0.24767035],
#        [0.24734595],
#        [0.2471309 ],
#        [0.24704099],
#        [0.24714768],
#        [0.24754493],
#        [0.24842776],
#        [0.24985892],
#        [0.25174856],
#        [0.25397468],
#        [0.2565559 ],
#        [0.2596397 ],
#        [0.2634348 ],
#        [0.2681532 ],
#        [0.2741087 ],
#        [0.28162476],
#        [0.2909295 ],
#        [0.302109  ],
#        [0.31551918],
#        [0.33172458],
#        [0.35087457],
#        [0.37303656],
#        [0.39702645],
#        [0.42099595],
#        [0.44371533],
#        [0.4658093 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00331268])

# %%
scale_factor = 1/0.00331268
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'g', label = "Actual Stock Price")
plt.plot(y_pred, 'r', label = "Predicted Stock Price")
plt.title('Tesla Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Model evaluation
#Calculation of mean absolute error

from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 14.34%

# %%
# Calculate Mean Squared Error and R2 Score
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 568.4407085892433

# %%
Pred = model.predict(x_test)
Pred = scaler.inverse_transform(Pred)
RMSE = np.sqrt(np.mean(Pred - y_test)**2)
RMSE
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 110.049807642358

# %%
predictions = model.predict(x_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
#Calculation of R2 score

from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.8642835902396577

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()

# %%
# Predict future value of 30 days
from tensorflow.keras.models import load_model

model = load_model('keras_model.h5')
last_100_days = data['Close'][-100:].values.reshape(-1, 1)
last_100_days_scaled = scaler.transform(last_100_days)

future_predictions = []
input_seq = last_100_days_scaled
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
for _ in range(30):
    x_input = input_seq[-100:].reshape(1, 100, 1)
    pred_price = model.predict(x_input, verbose=0)
    future_predictions.append(pred_price[0][0])
    input_seq = np.append(input_seq, pred_price)

# %%
# Transforming predictions back to original scale
future_predictions = np.array(future_predictions).reshape(-1, 1)
future_predictions = scaler.inverse_transform(future_predictions)

# %%
# Plotting the results
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Original Price')
plt.plot(range(len(data), len(data) + 30), future_predictions, label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
